# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import pyplot
# %matplotlib inline
from sklearn.linear_model import LinearRegression
def clean(s):
    a=pd.read_csv(s,encoding='latin-1')
    a.columns=a.iloc[0]
    a=a.drop(0,axis=0)
    a=a.set_index('Rk')
    cols=pd.Series(a.columns)
    for dup in cols[cols.duplicated()].unique(): 
        cols[cols[cols == dup].index.values.tolist()] = [dup + '.' + str(i) if i != 0 else dup for i in range(sum(cols == dup))]
  
    a.columns=cols
    return a

# %%
PATH = './Standard.csv'

# %%
Standard = clean(PATH)

# %%
PATH = './Shooting.csv'

# %%
Shooting = clean(PATH)

# %%
PATH = './Passing.csv'

# %%
PATH = './Passing.csv'

# %%
Passing = clean(PATH)

# %%
Passing
# Out:
# 0                        Player   Nation    Pos            Squad     Age  \
# Rk
# 1           Patrick van Aanholt   nl NED     DF   Crystal Palace  30-130
# 2                 Tammy Abraham  eng ENG     FW          Chelsea  23-096
# 3                     Che Adams  eng ENG     FW      Southampton  24-177
# 4              Tosin Adarabioyo  eng ENG     DF           Fulham  23-104
# 5                        Adrián   es ESP     GK        Liverpool  34-003
# ..                          ...      ...    ...              ...     ...
# 459  Andre-Frank Zambo Anguissa   cm CMR     MF           Fulham  25-051
# 460                 Andi Zeqiri   ch SUI  FW,DF         Brighton  21-198
# 461         Oleksandr Zinchenko   ua UKR     DF  Manchester City  24-022
# 462                Hakim Ziyech   ma MAR     FW          Chelsea  27-293
# 463                  Kurt Zouma   fr FRA     DF          Chelsea  26-071
#
# 0    Born   90s   Cmp   Att  Cmp%  ... Cmp%.3 Ast   xA  A-xA  KP 01-Mar PPA  \
# ...

# %%
PATH = './PassTypes.csv'

# %%
PassType = clean(PATH)

# %%
PATH = './GCA.csv'

# %%
GCA = clean(PATH)

# %%
PATH = './Defending.csv'

# %%
Defending = clean(PATH)

# %%
PATH = 'Possession.csv'

# %%
Possession = clean(PATH)

# %%
Standard
# Out:
# 0                        Player   Nation    Pos            Squad     Age  \
# Rk
# 1           Patrick van Aanholt   nl NED     DF   Crystal Palace  30-130
# 2                 Tammy Abraham  eng ENG     FW          Chelsea  23-096
# 3                     Che Adams  eng ENG     FW      Southampton  24-177
# 4              Tosin Adarabioyo  eng ENG     DF           Fulham  23-104
# 5                        Adrián   es ESP     GK        Liverpool  34-003
# ..                          ...      ...    ...              ...     ...
# 459  Andre-Frank Zambo Anguissa   cm CMR     MF           Fulham  25-051
# 460                 Andi Zeqiri   ch SUI  FW,DF         Brighton  21-198
# 461         Oleksandr Zinchenko   ua UKR     DF  Manchester City  24-022
# 462                Hakim Ziyech   ma MAR     FW          Chelsea  27-293
# 463                  Kurt Zouma   fr FRA     DF          Chelsea  26-071
#
# 0    Born  MP Starts    Min   90s  ... G+A-PK   xG npxG   xA  xG.1  xA.1  \
# ...

# %% [markdown]
# 1. Standard
# 2. Shooting
# 3. Passing
# 4. PassTypes
# 5. GCA
# 6. Defending
# 7. Posession

# %%
dfs=[]

# %%
dfs.append(Standard)
dfs.append(Shooting)
dfs.append(Passing)
dfs.append(PassType)
dfs.append(GCA)
dfs.append(Defending)
dfs.append(Possession)

# %%
result=pd.concat(dfs,axis=1)
result_cleaned=pd.concat(dfs,axis=1,join='inner')

# %%
len(list(result.columns))
# Out:
# 202

# %%
len(list(result_cleaned))
# Out:
# 202

# %%
result_cleaned= result.loc[:,~result.columns.duplicated()]

# %%
print(list(result_cleaned.columns))
# Out:
# ['Player', 'Nation', 'Pos', 'Squad', 'Age', 'Born', 'MP', 'Starts', 'Min', '90s', 'Gls', 'Ast', 'PK', 'PKatt', 'CrdY', 'CrdR', 'Gls.1', 'Ast.1', 'G+A', 'G-PK', 'G+A-PK', 'xG', 'npxG', 'xA', 'xG.1', 'xA.1', 'xG+xA', 'npxG.1', 'npxG+xA', 'Matches', 'Sh', 'SoT', 'SoT%', 'Sh/90', 'SoT/90', 'G/Sh', 'G/SoT', 'Dist', 'FK', 'npxG/Sh', 'G-xG', 'np:G-xG', 'Cmp', 'Att', 'Cmp%', 'TotDist', 'PrgDist', 'Cmp.1', 'Att.1', 'Cmp%.1', 'Cmp.2', 'Att.2', 'Cmp%.2', 'Cmp.3', 'Att.3', 'Cmp%.3', 'A-xA', 'KP', '01-Mar', 'PPA', 'CrsPA', 'Prog', 'Live', 'Dead', 'TB', 'Press', 'Sw', 'Crs', 'CK', 'In', 'Out', 'Str', 'Ground', 'Low', 'High', 'Left', 'Right', 'Head', 'TI', 'Other', 'Off', 'Out.1', 'Int', 'Blocks', 'SCA', 'SCA90', 'PassLive', 'PassDead', 'Drib', 'Fld', 'Def', 'GCA', 'GCA90', 'PassLive.1', 'PassDead.1', 'Drib.1', 'Sh.1', 'Fld.1', 'Def.1', 'OG', 'Tkl', 'TklW', 'Def 3rd', 'Mid 3rd', 'Att 3rd', 'Tkl.1', 'Tkl%', 'Past', 'Succ', '%', 'Def 3rd.1', 'Mid 3rd.1', 'Att 3rd.1', 'ShSv', 'Pass', 'Tkl+Int', 'Clr',
# ...

# %%
result_cleaned['xG']
# Out:
# Rk
# 1      0.7
# 2      5.1
# 3      3.6
# 4      0.5
# 5        0
#       ...
# 459      1
# 460    0.3
# 461    0.2
# 462    0.5
# 463    0.9
# Name: xG, Length: 463, dtype: object

# %%
~Standard.columns.duplicated()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
Standard.columns
# Out:
# Index(['Player', 'Nation', 'Pos', 'Squad', 'Age', 'Born', 'MP', 'Starts',
#        'Min', '90s', 'Gls', 'Ast', 'PK', 'PKatt', 'CrdY', 'CrdR', 'Gls.1',
#        'Ast.1', 'G+A', 'G-PK', 'G+A-PK', 'xG', 'npxG', 'xA', 'xG.1', 'xA.1',
#        'xG+xA', 'npxG.1', 'npxG+xA', 'Matches'],
#       dtype='object', name=0)

# %%
Standard
# Out:
# 0                        Player   Nation    Pos            Squad     Age  \
# Rk
# 1           Patrick van Aanholt   nl NED     DF   Crystal Palace  30-130
# 2                 Tammy Abraham  eng ENG     FW          Chelsea  23-096
# 3                     Che Adams  eng ENG     FW      Southampton  24-177
# 4              Tosin Adarabioyo  eng ENG     DF           Fulham  23-104
# 5                        Adrián   es ESP     GK        Liverpool  34-003
# ..                          ...      ...    ...              ...     ...
# 459  Andre-Frank Zambo Anguissa   cm CMR     MF           Fulham  25-051
# 460                 Andi Zeqiri   ch SUI  FW,DF         Brighton  21-198
# 461         Oleksandr Zinchenko   ua UKR     DF  Manchester City  24-022
# 462                Hakim Ziyech   ma MAR     FW          Chelsea  27-293
# 463                  Kurt Zouma   fr FRA     DF          Chelsea  26-071
#
# 0    Born  MP Starts    Min   90s  ... G+A-PK   xG npxG   xA  xG.1  xA.1  \
# ...

# %%
Standard.rename({"xG":"xG/90"}, axis='columns')
# Out:
# 0                        Player   Nation    Pos            Squad     Age  \
# Rk
# 1           Patrick van Aanholt   nl NED     DF   Crystal Palace  30-130
# 2                 Tammy Abraham  eng ENG     FW          Chelsea  23-096
# 3                     Che Adams  eng ENG     FW      Southampton  24-177
# 4              Tosin Adarabioyo  eng ENG     DF           Fulham  23-104
# 5                        Adrián   es ESP     GK        Liverpool  34-003
# ..                          ...      ...    ...              ...     ...
# 459  Andre-Frank Zambo Anguissa   cm CMR     MF           Fulham  25-051
# 460                 Andi Zeqiri   ch SUI  FW,DF         Brighton  21-198
# 461         Oleksandr Zinchenko   ua UKR     DF  Manchester City  24-022
# 462                Hakim Ziyech   ma MAR     FW          Chelsea  27-293
# 463                  Kurt Zouma   fr FRA     DF          Chelsea  26-071
#
# 0    Born  MP Starts    Min   90s  ... G+A-PK xG/90 npxG   xA  xG.1  xA.1  \
# ...

# %%
cols=pd.Series(Standard.columns)
for dup in cols[cols.duplicated()].unique(): 
    cols[cols[cols == dup].index.values.tolist()] = [dup + '.' + str(i) if i != 0 else dup for i in range(sum(cols == dup))]
    
# rename the columns with the cols list.
Standard.columns=cols
Standard
# Out:
# 0                        Player   Nation    Pos            Squad     Age  \
# Rk
# 1           Patrick van Aanholt   nl NED     DF   Crystal Palace  30-130
# 2                 Tammy Abraham  eng ENG     FW          Chelsea  23-096
# 3                     Che Adams  eng ENG     FW      Southampton  24-177
# 4              Tosin Adarabioyo  eng ENG     DF           Fulham  23-104
# 5                        Adrián   es ESP     GK        Liverpool  34-003
# ..                          ...      ...    ...              ...     ...
# 459  Andre-Frank Zambo Anguissa   cm CMR     MF           Fulham  25-051
# 460                 Andi Zeqiri   ch SUI  FW,DF         Brighton  21-198
# 461         Oleksandr Zinchenko   ua UKR     DF  Manchester City  24-022
# 462                Hakim Ziyech   ma MAR     FW          Chelsea  27-293
# 463                  Kurt Zouma   fr FRA     DF          Chelsea  26-071
#
# 0    Born  MP Starts    Min   90s  ... G+A-PK   xG npxG   xA  xG.1  xA.1  \
# ...

# %%
list(result_cleaned)
# Out:
# ['Player',
#  'Nation',
#  'Pos',
#  'Squad',
#  'Age',
#  'Born',
#  'MP',
#  'Starts',
#  'Min',
#  '90s',
#  'Gls',
#  'Ast',
#  'PK',
#  'PKatt',
#  'CrdY',
#  'CrdR',
#  'Gls.1',
#  'Ast.1',
#  'G+A',
#  'G-PK',
#  'G+A-PK',
#  'xG',
#  'npxG',
#  'xA',
#  'xG.1',
#  'xA.1',
#  'xG+xA',
#  'npxG.1',
#  'npxG+xA',
#  'Matches',
#  'Sh',
#  'SoT',
#  'SoT%',
#  'Sh/90',
#  'SoT/90',
#  'G/Sh',
#  'G/SoT',
#  'Dist',
#  'FK',
#  'npxG/Sh',
#  'G-xG',
#  'np:G-xG',
#  'Cmp',
#  'Att',
#  'Cmp%',
#  'TotDist',
#  'PrgDist',
#  'Cmp.1',
#  'Att.1',
#  'Cmp%.1',
#  'Cmp.2',
#  'Att.2',
#  'Cmp%.2',
#  'Cmp.3',
#  'Att.3',
#  'Cmp%.3',
#  'A-xA',
#  'KP',
#  '01-Mar',
#  'PPA',
#  'CrsPA',
#  'Prog',
#  'Live',
#  'Dead',
#  'TB',
#  'Press',
#  'Sw',
#  'Crs',
#  'CK',
#  'In',
#  'Out',
#  'Str',
#  'Ground',
#  'Low',
#  'High',
#  'Left',
#  'Right',
#  'Head',
#  'TI',
#  'Other',
#  'Off',
#  'Out.1',
#  'Int',
#  'Blocks',
#  'SCA',
#  'SCA90',
#  'PassLive',
#  'PassDead',
# ...

# %%
def merger(l):
    result=pd.concat(dfs,axis=1)
    cols=pd.Series(result.columns)
    for dup in cols[cols.duplicated()].unique(): 
        cols[cols[cols == dup].index.values.tolist()] = [dup + '.' + str(i) if i != 0 else dup for i in range(sum(cols == dup))]
        
    result.columns=cols
    return result

# %%
semi=merger(dfs)

# %%
list(semi.columns)
# Out:
# ['Player',
#  'Nation',
#  'Pos',
#  'Squad',
#  'Age',
#  'Born',
#  'MP',
#  'Starts',
#  'Min',
#  '90s',
#  'Gls',
#  'Ast',
#  'PK',
#  'PKatt',
#  'CrdY',
#  'CrdR',
#  'Gls.1',
#  'Ast.1',
#  'G+A',
#  'G-PK',
#  'G+A-PK',
#  'xG',
#  'npxG',
#  'xA',
#  'xG.1',
#  'xA.1',
#  'xG+xA',
#  'npxG.1',
#  'npxG+xA',
#  'Matches',
#  'Player.1',
#  'Nation.1',
#  'Pos.1',
#  'Squad.1',
#  'Age.1',
#  'Born.1',
#  '90s.1',
#  'Gls.1',
#  'Sh',
#  'SoT',
#  'SoT%',
#  'Sh/90',
#  'SoT/90',
#  'G/Sh',
#  'G/SoT',
#  'Dist',
#  'FK',
#  'PK.1',
#  'PKatt.1',
#  'xG.1',
#  'npxG.1',
#  'npxG/Sh',
#  'G-xG',
#  'np:G-xG',
#  'Matches.1',
#  'Player.2',
#  'Nation.2',
#  'Pos.2',
#  'Squad.2',
#  'Age.2',
#  'Born.2',
#  '90s.2',
#  'Cmp',
#  'Att',
#  'Cmp%',
#  'TotDist',
#  'PrgDist',
#  'Cmp.1',
#  'Att.1',
#  'Cmp%.1',
#  'Cmp.2',
#  'Att.2',
#  'Cmp%.2',
#  'Cmp.3',
#  'Att.3',
#  'Cmp%.3',
#  'Ast.1',
#  'xA.1',
#  'A-xA',
#  'KP',
#  '01-Mar',
#  'PPA',
#  'CrsPA',
#  'Prog',
# ...

# %%
fina={'Pos':'Pos', 'Min':'Min', 'Gls':'Gls',
       'Ast':"Ast", 'PK':'PK', 'Shots':'Sh', 'SoT':'SoT', 'Touches':'Touches', 'xG':'xG', 'npxG':'npxG', 'xA':'xA', 'SCA':'SCA',
       'GCA':'GCA', 'PassCmp':'Cmp', 'PassAtt':'Att', 'PassCmp%':'Cmp%', 'Through':'TB', 'PressPass':'Press',
       'Switches':'Sw', 'Crosses':'Crs', 'KP':'KP', 'Final ThirdPasses':'01-Mar', 'ProgressivePasses':'Prog',
       'PassPrgDist':'PrgDist', 'Carries':'Carries', 'TotDist':'TotDist','PrgDist':'PrgDist.1',  'Succ':'Succ.1', 'Att':'Att', 'Tkl':'Tkl',
       'TklW':'TklW','Press':'Press.1',  'PressSucc':'Succ', 'Press%':'%', 'Int':'Int', 'Tkl+Int':'Tkl+Int', 'Blocks':'Blocks',
       'Clr':'Clr', 'Def Pen':'Def Pen', 'Def 3rd Touches':'Def 3rd', 'Targ':'Targ', 'Rec':'Rec', 'Rec%':'Rec%'}

# %%
fina
# Out:
# {'Pos': 'Pos',
#  'Min': 'Min',
#  'Gls': 'Gls',
#  'Ast': 'Ast',
#  'PK': 'PK',
#  'Shots': 'Sh',
#  'SoT': 'SoT',
#  'Touches': 'Touches',
#  'xG': 'xG',
#  'npxG': 'npxG',
#  'xA': 'xA',
#  'SCA': 'SCA',
#  'GCA': 'GCA',
#  'PassCmp': 'Cmp',
#  'PassAtt': 'Att',
#  'PassCmp%': 'Cmp%',
#  'Through': 'TB',
#  'PressPass': 'Press',
#  'Switches': 'Sw',
#  'Crosses': 'Crs',
#  'KP': 'KP',
#  'Final ThirdPasses': '01-Mar',
#  'ProgressivePasses': 'Prog',
#  'PassPrgDist': 'PrgDist',
#  'Carries': 'Carries',
#  'TotDist': 'TotDist',
#  'PrgDist': 'PrgDist.1',
#  'Succ': 'Succ.1',
#  'Att': 'Att',
#  'Tkl': 'Tkl',
#  'TklW': 'TklW',
#  'Press': 'Press.1',
#  'PressSucc': 'Succ',
#  'Press%': '%',
#  'Int': 'Int',
#  'Tkl+Int': 'Tkl+Int',
#  'Blocks': 'Blocks',
#  'Clr': 'Clr',
#  'Def Pen': 'Def Pen',
#  'Def 3rd Touches': 'Def 3rd',
#  'Targ': 'Targ',
#  'Rec': 'Rec',
#  'Rec%': 'Rec%'}

# %%
hehe=list(fina.values())
haha=list(fina.keys())

# %%
dici={}
for i in range(len(haha)):
    dici[hehe[i]]=haha[i]

# %%
dici
# Out:
# {'Pos': 'Pos',
#  'Min': 'Min',
#  'Gls': 'Gls',
#  'Ast': 'Ast',
#  'PK': 'PK',
#  'Sh': 'Shots',
#  'SoT': 'SoT',
#  'Touches': 'Touches',
#  'xG': 'xG',
#  'npxG': 'npxG',
#  'xA': 'xA',
#  'SCA': 'SCA',
#  'GCA': 'GCA',
#  'Cmp': 'PassCmp',
#  'Att': 'Att',
#  'Cmp%': 'PassCmp%',
#  'TB': 'Through',
#  'Press': 'PressPass',
#  'Sw': 'Switches',
#  'Crs': 'Crosses',
#  'KP': 'KP',
#  '01-Mar': 'Final ThirdPasses',
#  'Prog': 'ProgressivePasses',
#  'PrgDist': 'PassPrgDist',
#  'Carries': 'Carries',
#  'TotDist': 'TotDist',
#  'PrgDist.1': 'PrgDist',
#  'Succ.1': 'Succ',
#  'Tkl': 'Tkl',
#  'TklW': 'TklW',
#  'Press.1': 'Press',
#  'Succ': 'PressSucc',
#  '%': 'Press%',
#  'Int': 'Int',
#  'Tkl+Int': 'Tkl+Int',
#  'Blocks': 'Blocks',
#  'Clr': 'Clr',
#  'Def Pen': 'Def Pen',
#  'Def 3rd': 'Def 3rd Touches',
#  'Targ': 'Targ',
#  'Rec': 'Rec',
#  'Rec%': 'Rec%'}

# %%
semi=semi.rename(dici)

# %%
semi=semi[hehe]

# %%
dici
# Out:
# {'Pos': 'Pos',
#  'Min': 'Min',
#  'Gls': 'Gls',
#  'Ast': 'Ast',
#  'PK': 'PK',
#  'Sh': 'Shots',
#  'SoT': 'SoT',
#  'Touches': 'Touches',
#  'xG': 'xG',
#  'npxG': 'npxG',
#  'xA': 'xA',
#  'SCA': 'SCA',
#  'GCA': 'GCA',
#  'Cmp': 'PassCmp',
#  'Att': 'Att',
#  'Cmp%': 'PassCmp%',
#  'TB': 'Through',
#  'Press': 'PressPass',
#  'Sw': 'Switches',
#  'Crs': 'Crosses',
#  'KP': 'KP',
#  '01-Mar': 'Final ThirdPasses',
#  'Prog': 'ProgressivePasses',
#  'PrgDist': 'PassPrgDist',
#  'Carries': 'Carries',
#  'TotDist': 'TotDist',
#  'PrgDist.1': 'PrgDist',
#  'Succ.1': 'Succ',
#  'Tkl': 'Tkl',
#  'TklW': 'TklW',
#  'Press.1': 'Press',
#  'Succ': 'PressSucc',
#  '%': 'Press%',
#  'Int': 'Int',
#  'Tkl+Int': 'Tkl+Int',
#  'Blocks': 'Blocks',
#  'Clr': 'Clr',
#  'Def Pen': 'Def Pen',
#  'Def 3rd': 'Def 3rd Touches',
#  'Targ': 'Targ',
#  'Rec': 'Rec',
#  'Rec%': 'Rec%'}

# %%
semi
# Out:
# 0      Pos    Min Gls Ast PK  Sh SoT Touches   xG npxG  ...     % Int Tkl+Int  \
# Rk                                                      ...
# 1       DF    829   0   1  0  12   5     641  0.7  0.7  ...    37  11      27
# 2       FW    782   6   1  0  27  11     278  5.1  5.1  ...    23   3       7
# 3       FW  1,346   4   4  0  28  14     499  3.6  3.6  ...  33.7   9      20
# 4       DF    990   0   0  0   9   0     584  0.5  0.5  ...  27.5   4      28
# 5       GK    180   0   0  0   0   0      69    0    0  ...     0   0       0
# ..     ...    ...  ..  .. ..  ..  ..     ...  ...  ...  ...   ...  ..     ...
# 459     MF  1,194   0   2  0  15   1     888    1    1  ...  26.2  13      82
# 460  FW,DF     64   0   0  0   5   0      20  0.3  0.3  ...    20   0       1
# 461     DF    103   0   0  0   1   1      82  0.2  0.2  ...    50   0       2
# 462     FW    451   1   3  0  10   3     353  0.5  0.5  ...  29.4   2       8
# ...

# %% [markdown]
# ## IMPORTANT

# %%
dfs=[]
dfs.append(Standard)
dfs.append(Shooting)
dfs.append(Passing)
dfs.append(PassType)
dfs.append(GCA)
dfs.append(Defending)
dfs.append(Possession)

# %%
def merger(l):
    # Takes as input  a list of dataframes
    # Returns a dataframe of cleaned required data
    result=pd.concat(dfs,axis=1)
    cols=pd.Series(result.columns)
    for dup in cols[cols.duplicated()].unique(): 
        cols[cols[cols == dup].index.values.tolist()] = [dup + '.' + str(i) if i != 0 else dup for i in range(sum(cols == dup))]
        
    result.columns=cols
    fina={'Pos': 'Pos',
         'Min': 'Min',
         'Gls': 'Gls',
         'Ast': 'Ast',
         'PK': 'PK',
         'Sh': 'Shots',
         'SoT': 'SoT',
         'Touches': 'Touches',
         'xG': 'xG',
         'npxG': 'npxG',
         'xA': 'xA',
         'SCA': 'SCA',
         'GCA': 'GCA',
         'Cmp': 'PassCmp',
         'Att': 'Att',
         'Cmp%': 'PassCmp%',
         'TB': 'Through',
         'Press': 'PressPass',
         'Sw': 'Switches',
         'Crs': 'Crosses',
         'KP': 'KP',
         '01-Mar': 'Final ThirdPasses',
         'Prog': 'ProgressivePasses',
         'PrgDist': 'PassPrgDist',
         'Carries': 'Carries',
         'TotDist': 'TotDist',
         'PrgDist.1': 'PrgDist',
         'Succ.1': 'Succ',
         'Tkl': 'Tkl',
         'TklW': 'TklW',
         'Press.1': 'Press',
         'Succ': 'PressSucc',
         '%': 'Press%',
         'Int': 'Int',
         'Tkl+Int': 'Tkl+Int',
         'Blocks': 'Blocks',
         'Clr': 'Clr',
         'Def Pen': 'Def Pen',
         'Def 3rd': 'Def 3rd Touches',
         'Targ': 'Targ',
         'Rec': 'Rec',
         'Rec%': 'Rec%'}
    hehe=list(fina.keys())
    hi=['Player',
         'Nation',
         'Squad',
         'Age',
         'Born',
         'MP']
    hi.extend(hehe)
    result=result.rename(dici)
    result=result[hi]
    for i in range(463):
        temp=result.loc[str(i+1)]['Nation']
        temp=temp.split()
        result.at[str(i+1),'Nation']=temp[1]
    return result

# %%
nice=merger(dfs)

# %%
nice
# Out:
# 0                        Player Nation            Squad     Age  Born  MP  \
# Rk
# 1           Patrick van Aanholt    NED   Crystal Palace  30-130  1990  10
# 2                 Tammy Abraham    ENG          Chelsea  23-096  1997  14
# 3                     Che Adams    ENG      Southampton  24-177  1996  16
# 4              Tosin Adarabioyo    ENG           Fulham  23-104  1997  11
# 5                        Adrián    ESP        Liverpool  34-003  1987   2
# ..                          ...    ...              ...     ...   ...  ..
# 459  Andre-Frank Zambo Anguissa    CMR           Fulham  25-051  1995  15
# 460                 Andi Zeqiri    SUI         Brighton  21-198  1999   2
# 461         Oleksandr Zinchenko    UKR  Manchester City  24-022  1996   2
# 462                Hakim Ziyech    MAR          Chelsea  27-293  1993   8
# 463                  Kurt Zouma    FRA          Chelsea  26-071  1994  15
#
# ...

# %%
nice.columns
# Out:
# Index(['Player', 'Nation', 'Squad', 'Age', 'Born', 'MP', 'Pos', 'Min', 'Gls',
#        'Ast', 'PK', 'Sh', 'SoT', 'Touches', 'xG', 'npxG', 'xA', 'SCA', 'GCA',
#        'Cmp', 'Att', 'Cmp%', 'TB', 'Press', 'Sw', 'Crs', 'KP', '01-Mar',
#        'Prog', 'PrgDist', 'Carries', 'TotDist', 'PrgDist.1', 'Succ.1', 'Tkl',
#        'TklW', 'Press.1', 'Succ', '%', 'Int', 'Tkl+Int', 'Blocks', 'Clr',
#        'Def Pen', 'Def 3rd', 'Targ', 'Rec', 'Rec%'],
#       dtype='object', name=0)

# %%
player=nice

# %%
player.rename(columns = {'Cmp':'PassCmp',
                       'Att':'PassAtt',
                       'Sh':'ShotsTaken',
                       'SoT':'ShotsOnTarg',
                       '01-Mar':'Pass1/3',
                       'Prog':'ProgressivePasses',
                       'PrgDist':'PrgDistPass',
                       'PrgDist.1':'PrgDistCarry',
                       'Succ.1':'SuccDrib',
                       'Press':'PressPass',
                       'Press.1':'PressAtt',
                       'Succ':'PressSucc',
                       '%':'PressSuccess%'}, inplace = True)

# %%
player.columns
# Out:
# Index(['Player', 'Nation', 'Squad', 'Age', 'Born', 'MP', 'Pos', 'Min', 'Gls',
#        'Ast', 'PK', 'ShotsTaken', 'ShotsOnTarg', 'Touches', 'xG', 'npxG', 'xA',
#        'SCA', 'GCA', 'PassCmp', 'PassAtt', 'Cmp%', 'TB', 'PressPass', 'Sw',
#        'Crs', 'KP', 'Pass1/3', 'ProgressivePasses', 'PrgDistPass', 'Carries',
#        'TotDist', 'PrgDistCarry', 'SuccDrib', 'Tkl', 'TklW', 'PressAtt',
#        'PressSucc', 'PressSuccess%', 'Int', 'Tkl+Int', 'Blocks', 'Clr',
#        'Def Pen', 'Def 3rd', 'Targ', 'Rec', 'Rec%'],
#       dtype='object', name=0)

# %%
listc=list(player.columns)
listc=listc[7:]
listc.append('Age')
listc.append('MP')
listc.append('Born')
player[listc]=player[listc].apply(pd.to_numeric,errors='coerce')

# %%
del player['Age']

# %%
player
# Out:
# 0                        Player Nation            Squad    Born  MP    Pos  \
# Rk
# 1           Patrick van Aanholt    NED   Crystal Palace  1990.0  10     DF
# 2                 Tammy Abraham    ENG          Chelsea  1997.0  14     FW
# 3                     Che Adams    ENG      Southampton  1996.0  16     FW
# 4              Tosin Adarabioyo    ENG           Fulham  1997.0  11     DF
# 5                        Adrián    ESP        Liverpool  1987.0   2     GK
# ..                          ...    ...              ...     ...  ..    ...
# 459  Andre-Frank Zambo Anguissa    CMR           Fulham  1995.0  15     MF
# 460                 Andi Zeqiri    SUI         Brighton  1999.0   2  FW,DF
# 461         Oleksandr Zinchenko    UKR  Manchester City  1996.0   2     DF
# 462                Hakim Ziyech    MAR          Chelsea  1993.0   8     FW
# 463                  Kurt Zouma    FRA          Chelsea  1994.0  15     DF
#
# ...

# %%
Creativity = player[['Player', 'Nation', 'Squad', 'Born', 'MP', 'Pos', 'Min','Ast', 'xA', 'SCA', 'GCA','TB','KP' ]].copy()
Creativity=Creativity.fillna(0)

# %%
Shooting = player[['Player', 'Nation', 'Squad', 'Born', 'MP', 'Pos', 'Min','Gls','ShotsTaken','ShotsOnTarg','xG']]

# %%
Shooting['Shooting']=Shooting['Gls']/(Shooting['xG'])
Shooting['Shooting']=Shooting['Shooting']/Shooting['ShotsTaken']
Shooting = Shooting.replace([np.inf, -np.inf], np.nan)
Shooting['Shooting'] = Shooting['Shooting'].fillna(0)
Shooting
# Out:
# D:\Tools\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# D:\Tools\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0                        Player Nation            Squad    Born  MP    Pos  \
# Rk
# 1           Patrick van Aanholt    NED   Crystal Palace  1990.0  10     DF
# ...

# %%
Press = player[['Player', 'Nation', 'Squad', 'Born', 'MP', 'Pos', 'Min','PressAtt', 'PressSucc', 'PressSuccess%' ]].copy()
Press = Press.replace([np.inf, -np.inf], np.nan)
Press=Press.fillna(0)

# %%
DefensiveContribution = player[['Player', 'Nation', 'Squad', 'Born', 'MP','Pos','Min','PressSucc', 'Blocks','Tkl+Int', 'Clr','Def Pen', 'Def 3rd' ]].copy()
DefensiveContribution =DefensiveContribution.fillna(0)

# %%
DefensiveEfficiency = player[['Player', 'Nation', 'Squad', 'Born', 'MP','Pos','Min','PressSuccess%', 'Blocks','Tkl+Int', 'Clr']].copy()

# %%
DefensiveEfficiency['Tackle Success']=player['TklW']/player['Tkl'] 
DefensiveEfficiency['Tackle Success'] = DefensiveEfficiency['Tackle Success'].fillna(0)

# %%
player.columns
# Out:
# Index(['Player', 'Nation', 'Squad', 'Born', 'MP', 'Pos', 'Min', 'Gls', 'Ast',
#        'PK', 'ShotsTaken', 'ShotsOnTarg', 'Touches', 'xG', 'npxG', 'xA', 'SCA',
#        'GCA', 'PassCmp', 'PassAtt', 'Cmp%', 'TB', 'PressPass', 'Sw', 'Crs',
#        'KP', 'Pass1/3', 'ProgressivePasses', 'PrgDistPass', 'Carries',
#        'TotDist', 'PrgDistCarry', 'SuccDrib', 'Tkl', 'TklW', 'PressAtt',
#        'PressSucc', 'PressSuccess%', 'Int', 'Tkl+Int', 'Blocks', 'Clr',
#        'Def Pen', 'Def 3rd', 'Targ', 'Rec', 'Rec%'],
#       dtype='object', name=0)

# %%
Passing = player[['Player', 'Nation', 'Squad', 'Born', 'MP','Pos','Min','PassCmp', 'Cmp%','PressPass','Sw', 'Crs']].copy()
Passing=Passing.fillna(0)

# %%
pressResistance = player[['Player', 'Nation', 'Squad', 'Born', 'MP','Pos','Min','Rec%','PressPass']].copy()
pressResistance=pressResistance.fillna(0)

# %%
Carrying = player[['Player', 'Nation', 'Squad', 'Born', 'MP','Carries', 'TotDist', 'PrgDistCarry']].copy()
Carrying=Carrying.fillna(0)

# %%
AttackInfluence = player[['Player', 'Nation', 'Squad', 'Born', 'MP','Pos','Min','Gls','Ast','xA','PassAtt','ProgressivePasses','Targ', 'KP']].copy()
AttackInfluence=AttackInfluence.fillna(0)

# %%
AttackingMentality = player[['Player', 'Nation', 'Squad', 'Born', 'MP','Pos','Min']].copy()
AttackingMentality['ProgressivePassing%'] = player['ProgressivePasses']/player['PassAtt']
AttackingMentality['ProgMovementWithBall%'] = player['PrgDistCarry']/player['TotDist']
AttackingMentality
# Out:
# 0                        Player Nation            Squad    Born  MP    Pos  \
# Rk
# 1           Patrick van Aanholt    NED   Crystal Palace  1990.0  10     DF
# 2                 Tammy Abraham    ENG          Chelsea  1997.0  14     FW
# 3                     Che Adams    ENG      Southampton  1996.0  16     FW
# 4              Tosin Adarabioyo    ENG           Fulham  1997.0  11     DF
# 5                        Adrián    ESP        Liverpool  1987.0   2     GK
# ..                          ...    ...              ...     ...  ..    ...
# 459  Andre-Frank Zambo Anguissa    CMR           Fulham  1995.0  15     MF
# 460                 Andi Zeqiri    SUI         Brighton  1999.0   2  FW,DF
# 461         Oleksandr Zinchenko    UKR  Manchester City  1996.0   2     DF
# 462                Hakim Ziyech    MAR          Chelsea  1993.0   8     FW
# 463                  Kurt Zouma    FRA          Chelsea  1994.0  15     DF
#
# 0      Min  ProgressivePassing%  ProgMovementWithBall%
# Rk
# ...

# %%
#AttackingMentality['MP'][0].datatype()
AttackingMentality=AttackingMentality.fillna(0)

# %%
#AttackingMentality[(AttackingMentality.Nation == 'POR')]

# %%
AttackingMentality=AttackingMentality[(AttackingMentality.Born>2000)]
AttackingMentality
# Out:
# 0               Player Nation            Squad    Born  MP    Pos    Min  \
# Rk
# 8      Rayan Aït Nouri    FRA           Wolves  2001.0   8     DF  530.0
# 106         Liam Delap    ENG  Manchester City  2003.0   1     FW   40.0
# 150        Eric García    ESP  Manchester City  2001.0   3     DF  201.0
# 155      Billy Gilmour    SCO          Chelsea  2001.0   2     MF   36.0
# 160     Anthony Gordon    ENG          Everton  2001.0   3  FW,MF   88.0
# 164    Mason Greenwood    ENG   Manchester Utd  2001.0  10     FW  620.0
# 169  Antwoine Hackford    ENG    Sheffield Utd  2004.0   1  DF,FW   11.0
# 183     Ki-Jana Hoever    NED           Wolves  2002.0   3     DF  121.0
# 203       Curtis Jones    ENG        Liverpool  2001.0  11     MF  672.0
# 264         Martinelli    BRA          Arsenal  2001.0   3     FW  155.0
# 319      Owen Otasowie    USA           Wolves  2001.0   4     MF  116.0
# 341       Jacob Ramsey    ENG      Aston Villa  2001.0   5  MF,FW  126.0
# ...

# %%
fig = plt.gcf()
fig.set_size_inches(16, 9)

ax=sns.scatterplot(x='ProgMovementWithBall%', y='ProgressivePassing%', data=AttackingMentality,
          #fit_reg=False,
          hue='Nation',
          #palette='Red',
          #text='Opponent',
          size=5,
          legend='brief')
          #height=8, aspect=1.5) 
sns.set(font_scale=2)
#plt.legend(bbox_to_anchor=(1.01, 0),borderaxespad=0)
#sns.set()
sns.axes_style("white")
ax.legend(loc=4, shadow=True, fontsize='x-small',facecolor='inherit',edgecolor='inherit',
         framealpha=0.1)

#plt.legend(prop={'size': 1}

#plt.ylim(0.025, None)
#plt.xlim(0.3, None)
xs=AttackingMentality['ProgMovementWithBall%']
ys=AttackingMentality['ProgressivePassing%']
op=AttackingMentality['Player']
for x,y,label in zip(xs,ys,op):

#    label = f("str(AttackingMentality['Opponent'][i])")
    
    
    if label=='Newcastle Utd':
        plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 size=15,
                 textcoords="offset points", # how to position the text
                 xytext=(-20,-10), # distance from text to points (x,y)
                 ha='left')
    else:
        plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 size=15,
                 textcoords="offset points", # how to position the text
                 xytext=(-10,10), # distance from text to points (x,y)
                 ha='left') # horizontal alignment can be left
#plt.savefig('our_plot_name.jpg', format='jpeg', dpi=70)
