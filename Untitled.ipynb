# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import pyplot
# %matplotlib inline
from sklearn.linear_model import LinearRegression

# %%
PATH = './Standard.csv'

# %%
Standard = clean(PATH)

# %%
PATH = './Shooting.csv'

# %%
Shooting = clean(PATH)

# %%
PATH = './Passing.csv'

# %%
Passing
# Out:
#     Unnamed: 0                  Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0           Rk                      Player     Nation        Pos
# 1            1         Patrick van Aanholt     nl NED         DF
# 2            2               Tammy Abraham    eng ENG         FW
# 3            3                   Che Adams    eng ENG         FW
# 4            4            Tosin Adarabioyo    eng ENG         DF
# ..         ...                         ...        ...        ...
# 459        459  Andre-Frank Zambo Anguissa     cm CMR         MF
# 460        460                 Andi Zeqiri     ch SUI      FW,DF
# 461        461         Oleksandr Zinchenko     ua UKR         DF
# 462        462                Hakim Ziyech     ma MAR         FW
# 463        463                  Kurt Zouma     fr FRA         DF
#
#           Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Total Unnamed: 9  ...  \
# 0              Squad        Age       Born        90s   Cmp        Att  ...
# ...

# %%
PATH = './Passing.csv'

# %%
Passing = clean(PATH)

# %%
Passing
# Out:
# 0                        Player   Nation    Pos            Squad     Age  \
# Rk
# 1           Patrick van Aanholt   nl NED     DF   Crystal Palace  30-130
# 2                 Tammy Abraham  eng ENG     FW          Chelsea  23-096
# 3                     Che Adams  eng ENG     FW      Southampton  24-177
# 4              Tosin Adarabioyo  eng ENG     DF           Fulham  23-104
# 5                        Adrián   es ESP     GK        Liverpool  34-003
# ..                          ...      ...    ...              ...     ...
# 459  Andre-Frank Zambo Anguissa   cm CMR     MF           Fulham  25-051
# 460                 Andi Zeqiri   ch SUI  FW,DF         Brighton  21-198
# 461         Oleksandr Zinchenko   ua UKR     DF  Manchester City  24-022
# 462                Hakim Ziyech   ma MAR     FW          Chelsea  27-293
# 463                  Kurt Zouma   fr FRA     DF          Chelsea  26-071
#
# 0    Born   90s   Cmp   Att  Cmp%  ...  Cmp% Ast   xA  A-xA  KP 01-Mar PPA  \
# ...

# %%
PATH = './PassTypes.csv'

# %%
PassType = clean(PATH)

# %%
PATH = './GCA.csv'

# %%
GCA = clean(PATH)

# %%
PATH = './Defending.csv'

# %%
Defending = clean(PATH)

# %%
PATH = 'Possession.csv'

# %%
Possession = clean(PATH)
